# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# En este cuaderno, se resumen las herramientas y ecosistemas de ciencia de datos.

# %% [markdown]
# **Objetivos:**
# - Dar a conocer los lenguajes más populares.
# - Dar a conocer las bibliotecas más comunes.
# - Dar a conocer las herramientas de código abierto comunmente utilizados.

# %% [markdown]
# Algunos de los lenguajes populares que utilizan los cientificos de datos son:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Algunas de las bibliotecas comúnmente utilizadas por los científicos de datos incluyen:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. TensorFlow

# %% [markdown]
# | Herramientas de Ciencia de Datos |
# | -------- |
# | Jupyter Notebook |
# | RStudio |
# | Apache Zeppelin |

# %% [markdown]
# ### A continuación, se presentan algunos ejemplos de evaluación de expresiones aritméticas en Python

# %% [markdown]
# Esta es una expresión aritmética simple para multiplicar y luego sumar enteros

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# Esta expresión convertirá 200 minutos a horas (dividiendo entre 60)

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Autor
# Emmanuel Flores
